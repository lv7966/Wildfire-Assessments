# %% [markdown]
# # Analyzing United States tornadoes

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Connect-your-GIS" data-toc-modified-id="Connect-your-GIS-1">Connect your GIS</a></span></li><li><span><a href="#Who-has-suffered-the-most?" data-toc-modified-id="Who-has-suffered-the-most?-2">Who has suffered the most?</a></span></li><li><span><a href="#Visualize-which-states-have-had-the-most-tornadoes." data-toc-modified-id="Visualize-which-states-have-had-the-most-tornadoes.-3">Visualize which states have had the most tornadoes.</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4">Conclusion</a></span></li></ul></div>

# %% [markdown]
# Tornadoes occur in many parts of the world, including Australia, Europe, Africa, Asia, and South America, but they are found most frequently in the United States. Outside the United States, two of the highest concentrations of tornadoes are found in Argentina and Bangladesh.
#
# Tornadoes are the most violent of all atmospheric storms and in the United States alone have caused an average of more than 80 deaths and 1,400 injuries each year (based on 1950–2011 data). A tornado is a narrow, violently rotating column of air that extends from the base of a thunderstorm to the ground. Tornado formation is complex, and no two tornadoes are the same; however, they need certain conditions to form, including intense or unseasonable heat. Wind speed within a tornado can vary from just above 0 mph up to 70 mph, with an average of 30 mph (NOAA). The Fujita damage scale is used to quantify the intensity of a tornado.

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# Explore the map of tornadoes across the United States: Twister! United States tornadoes from 1950 to 2012. Which states have had the most tornadoes? Using tornado location data from the United States severe weather report database, provided by the National Oceanic and Atmospheric Administration (NOAA)/National Weather Service Storm Prediction Center (http://www.spc.noaa.gov/gis/svrgis/), you can find the total number of tornadoes by state.

# %% [markdown]
# ## Connect your GIS

# %%
import arcgis
from arcgis import *
from arcgis.mapping import MapImageLayer

# %%
from arcgis.gis import GIS

# %% [markdown]
# To create the GIS object, we pass in the url and our login credentials as shown below

# %%
gis = GIS('home')

# %% [markdown]
# `Search`
# for the title: **tornado_lyr** layer.You can search the GIS for feature layer collections by specifying the item type as 'Feature Layer Collection' or 'Feature Layer'. You can also mention the owner name of the layer to get better search results.

# %%
data = gis.content.search('Tornadoes_and_Tracks owner: api_data_owner',
                           'Feature layer', outside_org=True)
print(data)
# Out:
# []

# %%
data = gis.content.search('tornado_lyr owner: demos_deldev',
                           'Feature layer', outside_org=True)
print(data)
# I had to change the feature layer name and owner to view the layer,
# since I did not have organizational access to the original layer
# Out:
# [<Item title:"tornado_lyr" type:Feature Layer Collection owner:demos_deldev>]

# %% [markdown]
# Display the list of results.

# %%
from IPython.display import display

for item in data:
    display(item)
# Out:
# <Item title:"tornado_lyr" type:Feature Layer Collection owner:demos_deldev>

# %% [markdown]
# Get the first item from the results.

# %%
item = data[0] #tornado_lyr

# %% [markdown]
# The code below cycles through the layers and print their names.

# %%
for lyr in item.layers:
    print(lyr.properties.name)
# Out:
# StatePop_5011
# Kansas_tracks
# MeanTrack_Merge
# Kansas_counties10
# Tornadoes_5011

# %% [markdown]
# Since the item is a Feature Layer Collection, accessing the layers property gives us a list of FeatureLayer objects. The StatePop_5011 layer is the first layer in this item.

# %%
#StatePop_5011
boundary = item.layers[0]
print(boundary.properties)

# the original code had an error in which it displayed the fourth element "tornadoes_5011" first rather than State_Pop_5011.
# this resulted in an "invalid geometry" error- solved by changing the item.layers value from 4 to 0 in this cell and 0 to 4 in the next.
# printing the boundary properties enabled me to see if the code was properly executing.
# Out:
# {
#   "currentVersion": 11,
#   "id": 0,
#   "name": "StatePop_5011",
#   "type": "Feature Layer",
#   "serviceItemId": "862842af46234f6295a60c082406298f",
#   "cacheMaxAge": 30,
#   "displayField": "NAME",
#   "description": "",
#   "copyrightText": "",
#   "defaultVisibility": true,
#   "editingInfo": {
#     "lastEditDate": 1546362813907,
#     "schemaLastEditDate": 1546362813907,
#     "dataLastEditDate": 1546362813907
#   },
#   "relationships": [],
#   "isDataVersioned": false,
#   "hasContingentValuesDefinition": false,
#   "supportsAppend": true,
#   "supportsCalculate": true,
#   "supportsASyncCalculate": true,
#   "supportsTruncate": true,
#   "supportsAttachmentsByUploadId": true,
#   "supportsAttachmentsResizing": true,
#   "supportsRollbackOnFailureParameter": true,
#   "supportsStatistics": true,
#   "supportsExceedsLimitStatistics": true,
#   "supportsAdvancedQueries": true,
#   "supportsValidateSql": true,
#   "supportsCoordinatesQuantization": true,
#   "supportsLayerOverrides": true,
#   "supportsTilesAndBasicQueriesMode": true,
#   "supportsFieldDescriptionProperty": true,
#   "supportsQuantizationEditMode": true,
#   "supportsApplyEditsWithGlobalIds": false,
#   "supportsMultiScaleGeometry": true,
#   "supportsReturningQueryGeometry": true,
#   "hasGeometryProperties": true,
#   "geometryProperties": {
#     "shapeAreaFieldName": "Shape__Area",
#     "shapeLengthFieldName": "Shape__Length",
#     "units": "esriMeters"
#   },
#   "advancedQueryCapabilities": {
#     "supportsPagination": true,
#     "supportsQueryAttachmentsCountOnly": true,
#     "supportsPaginationOnAggregatedQueries": true,
#     "supportsQueryRelatedPagination": true,
#     "supportsQueryWithDistance": true,
#     "supportsReturningQueryExtent": true,
#     "supportsStatistics": true,
#     "supportsOrderBy": true,
#     "supportsDistinct": true,
#     "supportsQueryWithResultType": true,
#     "supportsSqlExpression": true,
#     "supportsAdvancedQueryRelated": true,
#     "supportsCountDistinct": true,
#     "supportsPercentileStatistics": true,
#     "supportsSpatialAggregationStatistics": true,
#     "supportedSpatialAggregationStatistics": [
#       "EnvelopeAggregate",
#       "CentroidAggregate",
#       "ConvexHullAggregate"
#     ],
#     "supportsLod": true,
#     "supportsQueryWithLodSR": false,
#     "supportedLodTypes": [
#       "geohash"
#     ],
#     "supportsReturningGeometryCentroid": true,
#     "supportsReturningGeometryProperties": true,
#     "supportsQueryWithDatumTransformation": true,
#     "supportsHavingClause": true,
#     "supportsOutFieldSQLExpression": true,
#     "supportsMaxRecordCountFactor": true,
#     "supportsTopFeaturesQuery": true,
#     "supportsDisjointSpatialRel": true,
#     "supportsQueryWithCacheHint": true,
#     "supportedOperationsWithCacheHint": [
#       "query",
#       "queryTopFilter",
#       "queryAnalytics",
#       "queryAttachments",
#       "queryRelated"
#     ],
#     "supportsQueryAnalytic": true,
#     "supportsDefaultSR": true,
#     "supportsFullTextSearch": true
#   },
#   "advancedQueryAnalyticCapabilities": {
#     "supportsLinearRegression": true,
#     "supportsAsync": true,
#     "supportsPercentileAnalytic": true
#   },
#   "advancedEditingCapabilities": {
#     "supportedSqlFormatsInCalculate": [
#       "standard"
#     ],
#     "supportsAsyncApplyEdits": true,
#     "supportsReturnEditResults": true
#   },
#   "infoInEstimates": [
#     "extent",
#     "count"
#   ],
#   "useStandardizedQueries": true,
#   "geometryType": "esriGeometryPolygon",
#   "minScale": 0,
#   "maxScale": 0,
#   "extent": {
#     "xmin": -7424609.4096075315,
#     "ymin": -1656578.313903003,
#     "xmax": 2284962.0572485193,
#     "ymax": 7829121.004210887,
#     "spatialReference": {
#       "wkid": 102004,
#       "latestWkid": 102004
#     }
#   },
#   "drawingInfo": {
#     "renderer": {
#       "type": "simple",
#       "symbol": {
#         "type": "esriSFS",
#         "style": "esriSFSSolid",
#         "color": [
#           0,
#           0,
#           0,
#           0
#         ],
#         "outline": {
#           "type": "esriSLS",
#           "style": "esriSLSSolid",
#           "color": [
#             110,
#             110,
#             110,
#             255
#           ],
#           "width": 0.4
#         }
#       }
#     },
#     "scaleSymbols": true,
#     "transparency": 0,
#     "labelingInfo": null
#   },
#   "allowGeometryUpdates": true,
#   "hasAttachments": false,
#   "htmlPopupType": "esriServerHTMLPopupTypeAsHTMLText",
#   "hasMetadata": true,
#   "hasM": false,
#   "hasZ": false,
#   "objectIdField": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdField": "",
#   "typeIdField": "",
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "nullable": false,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATE",
#       "type": "esriFieldTypeString",
#       "alias": "STATE",
#       "sqlType": "sqlTypeOther",
#       "length": 2,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "NAME",
#       "type": "esriFieldTypeString",
#       "alias": "NAME",
#       "sqlType": "sqlTypeOther",
#       "length": 90,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "Average",
#       "type": "esriFieldTypeDouble",
#       "alias": "Average",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "AvgPop",
#       "type": "esriFieldTypeSingle",
#       "alias": "AvgPop",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "Shape__Area",
#       "type": "esriFieldTypeDouble",
#       "alias": "Shape__Area",
#       "sqlType": "sqlTypeDouble",
#       "nullable": true,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "Shape__Length",
#       "type": "esriFieldTypeDouble",
#       "alias": "Shape__Length",
#       "sqlType": "sqlTypeDouble",
#       "nullable": true,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     }
#   ],
#   "indexes": [
#     {
#       "name": "PK__TORNADO___F4B70D855689597B",
#       "fields": "OBJECTID",
#       "isAscending": true,
#       "isUnique": true,
#       "description": ""
#     },
#     {
#       "name": "user_18678.TORNADO_LYR_STATEPOP_5011_Shape_sidx",
#       "fields": "Shape",
#       "isAscending": true,
#       "isUnique": false,
#       "description": ""
#     },
#     {
#       "name": "Shape__Area_Index",
#       "fields": "Shape__Area",
#       "isAscending": true,
#       "isUnique": false,
#       "description": ""
#     },
#     {
#       "name": "Shape__Length_Index",
#       "fields": "Shape__Length",
#       "isAscending": true,
#       "isUnique": false,
#       "description": ""
#     }
#   ],
#   "dateFieldsTimeReference": {
#     "timeZone": "UTC",
#     "respectsDaylightSaving": false
#   },
#   "preferredTimeReference": null,
#   "types": [],
#   "templates": [
#     {
#       "name": "StatePop_5011",
#       "description": "",
#       "drawingTool": "esriFeatureEditToolPolygon",
#       "prototype": {
#         "attributes": {
#           "Average": null,
#           "AvgPop": null,
#           "STATE": null,
#           "NAME": null
#         }
#       }
#     }
#   ],
#   "supportedQueryFormats": "JSON, geoJSON, PBF",
#   "supportedAppendFormats": "sqlite,geoPackage,shapefile,filegdb,featureCollection,geojson,csv,excel",
#   "supportedExportFormats": "csv,shapefile,sqlite,geoPackage,filegdb,featureCollection,geojson,excel",
#   "supportedSpatialRelationships": [
#     "esriSpatialRelIntersects",
#     "esriSpatialRelContains",
#     "esriSpatialRelCrosses",
#     "esriSpatialRelEnvelopeIntersects",
#     "esriSpatialRelIndexIntersects",
#     "esriSpatialRelOverlaps",
#     "esriSpatialRelTouches",
#     "esriSpatialRelWithin",
#     "esriSpatialRelDisjoint",
#     "esriSpatialRelRelation"
#   ],
#   "supportedContingentValuesFormats": "JSON, PBF",
#   "supportedSyncDataOptions": 4,
#   "hasStaticData": true,
#   "maxRecordCount": 2000,
#   "standardMaxRecordCount": 4000,
#   "standardMaxRecordCountNoGeometry": 32000,
#   "tileMaxRecordCount": 4000,
#   "maxRecordCountFactor": 1,
#   "capabilities": "Query,Extract"
# }

# %%
#Tornadoes_5011
tornado_lyr = item.layers[4]
print(tornado_lyr.properties)
# Out:
# {
#   "currentVersion": 11,
#   "id": 4,
#   "name": "Tornadoes_5011",
#   "type": "Feature Layer",
#   "serviceItemId": "862842af46234f6295a60c082406298f",
#   "cacheMaxAge": 30,
#   "displayField": "STATE",
#   "description": "",
#   "copyrightText": "",
#   "defaultVisibility": true,
#   "editingInfo": {
#     "lastEditDate": 1546362813939,
#     "schemaLastEditDate": 1546362813939,
#     "dataLastEditDate": 1546362813939
#   },
#   "relationships": [],
#   "isDataVersioned": false,
#   "hasContingentValuesDefinition": false,
#   "supportsAppend": true,
#   "supportsCalculate": true,
#   "supportsASyncCalculate": true,
#   "supportsTruncate": true,
#   "supportsAttachmentsByUploadId": true,
#   "supportsAttachmentsResizing": true,
#   "supportsRollbackOnFailureParameter": true,
#   "supportsStatistics": true,
#   "supportsExceedsLimitStatistics": true,
#   "supportsAdvancedQueries": true,
#   "supportsValidateSql": true,
#   "supportsCoordinatesQuantization": true,
#   "supportsLayerOverrides": true,
#   "supportsTilesAndBasicQueriesMode": true,
#   "supportsFieldDescriptionProperty": true,
#   "supportsQuantizationEditMode": true,
#   "supportsApplyEditsWithGlobalIds": false,
#   "supportsReturningQueryGeometry": true,
#   "advancedQueryCapabilities": {
#     "supportsPagination": true,
#     "supportsQueryAttachmentsCountOnly": true,
#     "supportsPaginationOnAggregatedQueries": true,
#     "supportsQueryRelatedPagination": true,
#     "supportsQueryWithDistance": true,
#     "supportsReturningQueryExtent": true,
#     "supportsStatistics": true,
#     "supportsOrderBy": true,
#     "supportsDistinct": true,
#     "supportsQueryWithResultType": true,
#     "supportsSqlExpression": true,
#     "supportsAdvancedQueryRelated": true,
#     "supportsCountDistinct": true,
#     "supportsPercentileStatistics": true,
#     "supportsSpatialAggregationStatistics": true,
#     "supportedSpatialAggregationStatistics": [
#       "EnvelopeAggregate",
#       "CentroidAggregate",
#       "ConvexHullAggregate"
#     ],
#     "supportsLod": true,
#     "supportsQueryWithLodSR": false,
#     "supportedLodTypes": [
#       "geohash"
#     ],
#     "supportsReturningGeometryCentroid": false,
#     "supportsQueryWithDatumTransformation": true,
#     "supportsHavingClause": true,
#     "supportsOutFieldSQLExpression": true,
#     "supportsMaxRecordCountFactor": true,
#     "supportsTopFeaturesQuery": true,
#     "supportsDisjointSpatialRel": true,
#     "supportsQueryWithCacheHint": true,
#     "supportedOperationsWithCacheHint": [
#       "query",
#       "queryTopFilter",
#       "queryAnalytics",
#       "queryAttachments",
#       "queryRelated"
#     ],
#     "supportsQueryAnalytic": true,
#     "supportsDefaultSR": true,
#     "supportsFullTextSearch": true
#   },
#   "advancedQueryAnalyticCapabilities": {
#     "supportsLinearRegression": true,
#     "supportsAsync": true,
#     "supportsPercentileAnalytic": true
#   },
#   "advancedEditingCapabilities": {
#     "supportedSqlFormatsInCalculate": [
#       "standard"
#     ],
#     "supportsAsyncApplyEdits": true,
#     "supportsReturnEditResults": true
#   },
#   "infoInEstimates": [
#     "extent",
#     "count"
#   ],
#   "useStandardizedQueries": true,
#   "geometryType": "esriGeometryPoint",
#   "minScale": 0,
#   "maxScale": 0,
#   "extent": {
#     "xmin": -6279239.836414542,
#     "ymin": -1835230.7832643464,
#     "xmax": 10841282.153531888,
#     "ymax": 3888096.0658399058,
#     "spatialReference": {
#       "wkid": 102004,
#       "latestWkid": 102004
#     }
#   },
#   "drawingInfo": {
#     "renderer": {
#       "type": "simple",
#       "symbol": {
#         "type": "esriPMS",
#         "url": "7233fdc44a4d4e6812d4d003c96b975d",
#         "imageData": "iVBORw0KGgoAAAANSUhEUgAAAAYAAAAGCAYAAADgzO9IAAAACXBIWXMAAA7EAAAOxAGVKw4bAAAAUElEQVQImXXNsQmAQABD0Xd42GuttWu4qK1TuIgbCIKFhZ2chZ5gYSAQPiSJfhRzSPRoMQbO+MAGEwqUGHLjwI4KyzsV2BId6sD8+QisboMLX/YNTwospfYAAAAASUVORK5CYII=",
#         "contentType": "image/png",
#         "width": 4,
#         "height": 4,
#         "angle": 0,
#         "xoffset": 0,
#         "yoffset": 0
#       }
#     },
#     "scaleSymbols": true,
#     "transparency": 0,
#     "labelingInfo": null
#   },
#   "allowGeometryUpdates": true,
#   "hasAttachments": false,
#   "htmlPopupType": "esriServerHTMLPopupTypeAsHTMLText",
#   "hasMetadata": true,
#   "hasM": false,
#   "hasZ": false,
#   "objectIdField": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdField": "",
#   "typeIdField": "",
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "nullable": false,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "OM",
#       "type": "esriFieldTypeDouble",
#       "alias": "OM",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "YEAR",
#       "type": "esriFieldTypeDouble",
#       "alias": "YEAR",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "MONTH",
#       "type": "esriFieldTypeDouble",
#       "alias": "MONTH",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "DAY",
#       "type": "esriFieldTypeDouble",
#       "alias": "DAY",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "DATE",
#       "type": "esriFieldTypeDate",
#       "alias": "DATE",
#       "sqlType": "sqlTypeOther",
#       "length": 8,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "TIME",
#       "type": "esriFieldTypeDouble",
#       "alias": "TIME",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "TIMEZONE",
#       "type": "esriFieldTypeDouble",
#       "alias": "TIMEZONE",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATE",
#       "type": "esriFieldTypeString",
#       "alias": "STATE",
#       "sqlType": "sqlTypeOther",
#       "length": 254,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "FIPS",
#       "type": "esriFieldTypeDouble",
#       "alias": "FIPS",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATENUMBE",
#       "type": "esriFieldTypeDouble",
#       "alias": "STATENUMBE",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "FSCALE",
#       "type": "esriFieldTypeDouble",
#       "alias": "FSCALE",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "INJURIES",
#       "type": "esriFieldTypeDouble",
#       "alias": "INJURIES",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "FATALITIES",
#       "type": "esriFieldTypeDouble",
#       "alias": "FATALITIES",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LOSS",
#       "type": "esriFieldTypeDouble",
#       "alias": "LOSS",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "CROPLOSS",
#       "type": "esriFieldTypeDouble",
#       "alias": "CROPLOSS",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "SLAT",
#       "type": "esriFieldTypeDouble",
#       "alias": "SLAT",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "SLON",
#       "type": "esriFieldTypeDouble",
#       "alias": "SLON",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ELAT",
#       "type": "esriFieldTypeDouble",
#       "alias": "ELAT",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ELON",
#       "type": "esriFieldTypeDouble",
#       "alias": "ELON",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LENGTH",
#       "type": "esriFieldTypeDouble",
#       "alias": "LENGTH",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "WIDTH",
#       "type": "esriFieldTypeDouble",
#       "alias": "WIDTH",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "NS",
#       "type": "esriFieldTypeDouble",
#       "alias": "NS",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "SN",
#       "type": "esriFieldTypeDouble",
#       "alias": "SN",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "SG",
#       "type": "esriFieldTypeDouble",
#       "alias": "SG",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "F1",
#       "type": "esriFieldTypeDouble",
#       "alias": "F1",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "F2",
#       "type": "esriFieldTypeDouble",
#       "alias": "F2",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "F3",
#       "type": "esriFieldTypeDouble",
#       "alias": "F3",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "F4",
#       "type": "esriFieldTypeDouble",
#       "alias": "F4",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "FSCALE2",
#       "type": "esriFieldTypeSmallInteger",
#       "alias": "FSCALE2",
#       "sqlType": "sqlTypeOther",
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     }
#   ],
#   "indexes": [
#     {
#       "name": "PK__TORNADO___F4B70D85E4A6F629",
#       "fields": "OBJECTID",
#       "isAscending": true,
#       "isUnique": true,
#       "description": ""
#     },
#     {
#       "name": "user_18678.TORNADO_LYR_TORNADOES_5011_Shape_sidx",
#       "fields": "Shape",
#       "isAscending": true,
#       "isUnique": false,
#       "description": ""
#     }
#   ],
#   "dateFieldsTimeReference": {
#     "timeZone": "UTC",
#     "respectsDaylightSaving": false
#   },
#   "preferredTimeReference": null,
#   "types": [],
#   "templates": [
#     {
#       "name": "Tornadoes_5011",
#       "description": "",
#       "drawingTool": "esriFeatureEditToolPoint",
#       "prototype": {
#         "attributes": {
#           "F4": null,
#           "FSCALE2": null,
#           "OM": null,
#           "YEAR": null,
#           "MONTH": null,
#           "DAY": null,
#           "DATE": null,
#           "TIME": null,
#           "TIMEZONE": null,
#           "STATE": null,
#           "FIPS": null,
#           "STATENUMBE": null,
#           "FSCALE": null,
#           "INJURIES": null,
#           "FATALITIES": null,
#           "LOSS": null,
#           "CROPLOSS": null,
#           "SLAT": null,
#           "SLON": null,
#           "ELAT": null,
#           "ELON": null,
#           "LENGTH": null,
#           "WIDTH": null,
#           "NS": null,
#           "SN": null,
#           "SG": null,
#           "F1": null,
#           "F2": null,
#           "F3": null
#         }
#       }
#     }
#   ],
#   "supportedQueryFormats": "JSON, geoJSON, PBF",
#   "supportedAppendFormats": "sqlite,geoPackage,shapefile,filegdb,featureCollection,geojson,csv,excel",
#   "supportedExportFormats": "csv,shapefile,sqlite,geoPackage,filegdb,featureCollection,geojson,excel",
#   "supportedSpatialRelationships": [
#     "esriSpatialRelIntersects",
#     "esriSpatialRelContains",
#     "esriSpatialRelCrosses",
#     "esriSpatialRelEnvelopeIntersects",
#     "esriSpatialRelIndexIntersects",
#     "esriSpatialRelOverlaps",
#     "esriSpatialRelTouches",
#     "esriSpatialRelWithin",
#     "esriSpatialRelDisjoint",
#     "esriSpatialRelRelation"
#   ],
#   "supportedContingentValuesFormats": "JSON, PBF",
#   "supportedSyncDataOptions": 4,
#   "hasStaticData": true,
#   "maxRecordCount": 2000,
#   "standardMaxRecordCount": 32000,
#   "standardMaxRecordCountNoGeometry": 32000,
#   "tileMaxRecordCount": 8000,
#   "maxRecordCountFactor": 1,
#   "capabilities": "Query,Extract"
# }

# %% [markdown]
# `Aggregate_points` tool summarizes data from spot measurements by area. To learn more about this tool and the formula it uses, refer to the documentation <a href="http://doc.arcgis.com/en/arcgis-online/analyze/aggregate-points.htm">here</a>.

# %%
from arcgis.features.summarize_data import aggregate_points
from datetime import datetime as dt

# %% [markdown]
# Please change the output_name if this is not the first you run the cell below.

# %%
agg_points = aggregate_points(point_layer=tornado_lyr, 
                              polygon_layer=boundary, 
                              keep_boundaries_with_no_points=True,
                              output_name="agg_tornado_points" + str(dt.now().microsecond))
# Out:
# {"cost": 56.272}

# %%
agg_points
# Out:
# <Item title:"agg_tornado_points377940" type:Feature Layer Collection owner:lv7966>

# %%
agg_lyr = agg_points.layers[0]

# %% [markdown]
# The GIS object includes a map widget for displaying geographic locations, visualizing GIS content, as well as the results of your analysis. To use the map widget, call ``gis.map()`` and assign it to a variable.

# %%
m1 = gis.map('US')
m1.add_layer(agg_lyr)
m1
# the map will not display the feature layer due to a bug where a pop up requests an ArcGIS sign in
# but would not allow me to type characters in the login menu
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-180bdb74-e793-449d-b872-99653abf75ad"><img src=""></img></div>
# <div class="map-html-embed-preview-180bdb74-e793-449d-b872-99653abf75ad"></div>

# %% [markdown]
# ###### Who has suffered the most?

# %% [markdown]
# There can be many devastating effects from a tornado, including loss of life, injuries, property damage, and financial losses. To identify populations that have been affected by tornadoes, you can aggregate the number of tornadoes to the state level and normalize by population.

# %%
m2 = gis.map('US', zoomlevel=4)

# %% [markdown]
# ![](tornado_img/5.PNG)

# %%
m2.add_layer(agg_lyr, {
               "renderer":"ClassedColorRenderer",
               "field_name":"AvgPop",
               "opacity":0.7
              })

# %%
m2.legend = True

# %%
m2
# same issue as above with map not displaying feature layer
# Out:
# MapView(jupyter_target='notebook', layout=Layout(height='400px', width='100%'), legend=True, ready=True)
# <div class="map-static-img-preview-74f1a9f5-d331-4e06-993a-3b8b802794d8"><img src=""></img></div>
# <div class="map-html-embed-preview-74f1a9f5-d331-4e06-993a-3b8b802794d8"></div>

# %% [markdown]
# Feature layers hosted can be easily read into a Spatially Enabled DataFrame using the from_layer method. Once you read it into a SEDF object, you can create reports, manipulate the data, or convert it to a form that is comfortable and makes sense for its intended purpose.

# %%
import pandas as pd
sdf = pd.DataFrame.spatial.from_layer(agg_lyr)

# %%
sdf.head()
# Out:
#    OBJECTID STATE        NAME       Average        AvgPop  Point_Count  \
# 0         1    02      Alaska  4.230640e+05  4.230640e+05            3
# 1         2    27   Minnesota  4.130647e+06  4.130647e+06         1590
# 2         3    53  Washington  4.303187e+06  4.303187e+06          100
# 3         4    30     Montana  7.766022e+05  7.766022e+05          383
# 4         5    16       Idaho  9.562094e+05  9.562094e+05          194
#
#    AnalysisArea                                              SHAPE
# 0  1.524011e+06  {"rings": [[[-3009776.5257, 4704174.9531], [-3...
# 1  2.185680e+05  {"rings": [[[62392.6840000004, 1132755.8398], ...
# 2  1.762861e+05  {"rings": [[[-1947298.6449, 1399434.5065], [-1...
# 3  3.808304e+05  {"rings": [[[-1470226.2844, 1273708.4356], [-1...
# 4  2.164428e+05  {"rings": [[[-1470226.2844, 1273708.4356], [-1...

# %%
sdf.shape
# Out:
# (51, 8)

# %% [markdown]
# ## Visualize which states have had the most tornadoes.

# %%
sdf.sort_values(by='Point_Count', ascending=False, axis=0, inplace=True)

# %%
df = sdf[0:10]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
plt.bar(df.NAME, df.Point_Count)
plt.xlabel('NAME', fontsize=7)
plt.ylabel('point_count', fontsize=7)
plt.xticks(fontsize=8, rotation=45)
plt.title('The ten states with the highest number of tornadoes')
plt.show()

# %% [markdown]
# Number of tornadoes by state, 1950–2011
#
# Some states are subject to many more tornadoes than others. Over a 62-year period (1950–2011), Texas had by far the most tornadoes (with 7,935), followed by Kansas (with 3,713), while others such as Vermont, Rhode Island, and the District of Columbia had fewer than 50. The ten states shown in the graph below had 20 percent of the total number of tornadoes.

# %% [markdown]
# ## Conclusion
#
# In this notebook, we demonstrate how to use aggregation analysis to summarize the number of data points within each polygon. Thus, using `aggregate_points()` method, we arrive at the number of tornadoes that hit each state. and published the aggregation results as an online service. Mapping results often show new insights that lead to deeper understanding and more clearly defined analysis.

# %%
# there were some flaws with the code (the original owner mixed up the order of feature layers causing an "invalid geometry"
# error) and there was a map that I did not have authorization to view. Additionally a bug prevented visualization of 
# certain spatial data on m1 and m2. However, the code was still able to be run through and conclusions remain the same.

# %%
# code was tested on 2.21.23 by Luca Venegoni
